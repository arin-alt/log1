# %%
# Removing warnings
import os
os.environ["OMP_NUM_THREADS"] = "1"

# %%
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import joblib

# %% [markdown]
# <h2 style="padding: 0.5rem; background-color: #513d5c; color: white;">Data Import</h2>

# %%
inventory_df = pd.read_json('./data/exported_listings.json')
stock_df = pd.read_json('./data/stock_listing_v2_1.json')
inventory_df = inventory_df.merge(stock_df, on='_id')

inventory_df
# Out:
#                             _id  itemCode         title  \
# 0      67b5d1d3965831513a85d8be       100    Ventilator
# 1      67b5d1d3965831513a85d8be       100    Ventilator
# 2      67b5d1d3965831513a85d8be       100    Ventilator
# 3      67b5d1d3965831513a85d8be       100    Ventilator
# 4      67b5d1d3965831513a85d8be       100    Ventilator
# ...                         ...       ...           ...
# 18643  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18644  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18645  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18646  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18647  67b5d1d3965831513a85d8cf       209  Cotton Rolls
#
#                                              description    category  \
# 0      A medical device that supports or takes over b...   Equipment
# 1      A medical device that supports or takes over b...   Equipment
# 2      A medical device that supports or takes over b...   Equipment
# 3      A medical device that supports or takes over b...   Equipment
# 4      A medical device that supports or takes over b...   Equipment
# ...                                                  ...         ...
# 18643  Soft, absorbent materials used in medical appl...  Consumable
# 18644  Soft, absorbent materials used in medical appl...  Consumable
# 18645  Soft, absorbent materials used in medical appl...  Consumable
# 18646  Soft, absorbent materials used in medical appl...  Consumable
# 18647  Soft, absorbent materials used in medical appl...  Consumable
#
#       abcCategory  minStockLevel  maxStockLevel                 createdBy  \
# 0               C              3             25  67b1fdb293bfc8e17f896b31
# 1               C              3             25  67b1fdb293bfc8e17f896b31
# 2               C              3             25  67b1fdb293bfc8e17f896b31
# 3               C              3             25  67b1fdb293bfc8e17f896b31
# 4               C              3             25  67b1fdb293bfc8e17f896b31
# ...           ...            ...            ...                       ...
# 18643           C            300           2000  67b1fdb293bfc8e17f896b31
# 18644           C            300           2000  67b1fdb293bfc8e17f896b31
# 18645           C            300           2000  67b1fdb293bfc8e17f896b31
# 18646           C            300           2000  67b1fdb293bfc8e17f896b31
# 18647           C            300           2000  67b1fdb293bfc8e17f896b31
#
#        status                 createdAt       date stock_status  unit_cost  \
# 0      active  2025-02-19T12:42:59.839Z 2022-01-01    Available    2628329
# 1      active  2025-02-19T12:42:59.839Z 2022-01-02    Available    3140148
# 2      active  2025-02-19T12:42:59.839Z 2022-01-03    Available    2900449
# 3      active  2025-02-19T12:42:59.839Z 2022-01-04    Available    3160811
# 4      active  2025-02-19T12:42:59.839Z 2022-01-05    Available    2502553
# ...       ...                       ...        ...          ...        ...
# 18643  active  2025-02-19T12:42:59.839Z 2024-12-27    Available        149
# 18644  active  2025-02-19T12:42:59.839Z 2024-12-28    Available         87
# 18645  active  2025-02-19T12:42:59.839Z 2024-12-29    Available         64
# 18646  active  2025-02-19T12:42:59.839Z 2024-12-30    Available         91
# 18647  active  2025-02-19T12:42:59.839Z 2024-12-31    Available        119
#
#        current_stock  avg_usage_per_day  \
# 0                 22                  5
# 1                 22                  1
# 2                 18                  1
# 3                  8                  1
# 4                 21                  1
# ...              ...                ...
# 18643           1881                299
# 18644            606                296
# 18645           1100                178
# 18646            571                148
# 18647           1201                259
#
#                                       vendor_name    vendor_contact  \
# 0                 Coleman-Bailey Medical Supplies  +63 906 473 8909
# 1                    Wang-Foster Medical Supplies  +63 922 748 0407
# 2                      Wu-Flores Medical Supplies  +63 973 346 5410
# 3                      Wu-Flores Medical Supplies  +63 973 346 5410
# 4                    Wang-Foster Medical Supplies  +63 922 748 0407
# ...                                           ...               ...
# 18643                Wang-Foster Medical Supplies  +63 922 748 0407
# 18644             Coleman-Bailey Medical Supplies  +63 906 473 8909
# 18645                  Wu-Flores Medical Supplies  +63 973 346 5410
# 18646             Coleman-Bailey Medical Supplies  +63 906 473 8909
# 18647  Khan, Johnston and Nguyen Medical Supplies  +63 962 472 5531
#
#        expiration_date      storageLocation
# 0                  NaN   ICU Equipment Room
# 1                  NaN   ICU Equipment Room
# 2                  NaN   ICU Equipment Room
# 3                  NaN   ICU Equipment Room
# 4                  NaN   ICU Equipment Room
# ...                ...                  ...
# 18643     1.892938e+12  Medical Supply Room
# 18644     1.893024e+12  Medical Supply Room
# 18645     1.893110e+12  Medical Supply Room
# 18646     1.893197e+12  Medical Supply Room
# 18647     1.893283e+12  Medical Supply Room
#
# [18648 rows x 20 columns]

# %%
patient_df = pd.read_csv('./data/patient_data_v2.csv')
patient_df
# Out:
#        diagnosis_id        date primary_diagnosis procedure_performed  \
# 0                 1  2022-09-08         Pneumonia         Chest X-Ray
# 1                 1  2022-10-23         Pneumonia         Chest X-Ray
# 2                 1  2022-07-06         Pneumonia         Chest X-Ray
# 3                 1  2022-04-11         Pneumonia         Chest X-Ray
# 4                 1  2023-11-08         Pneumonia         Chest X-Ray
# ...             ...         ...               ...                 ...
# 33209          2692  2023-08-29          COVID-19         Chest X-Ray
# 33210          2692  2024-02-16          COVID-19         Chest X-Ray
# 33211          2692  2024-03-26          COVID-19         Chest X-Ray
# 33212          2692  2023-04-21          COVID-19         Chest X-Ray
# 33213          2692  2024-11-12          COVID-19         Chest X-Ray
#
#            item_used   item_type
# 0      Surgical Mask  Consumable
# 1             Gloves  Consumable
# 2               Gown  Consumable
# 3        Face Shield  Consumable
# 4      X-Ray Machine   Equipment
# ...              ...         ...
# 33209  Surgical Mask  Consumable
# 33210         Gloves  Consumable
# 33211           Gown  Consumable
# 33212    Face Shield  Consumable
# 33213  X-Ray Machine   Equipment
#
# [33214 rows x 6 columns]

# %% [markdown]
# <h2 style='font-size: 2.5rem; font-weight: bold; text-align: center; padding: 1rem 0'>Exploratory Data Analysis (EDA)</h2>

# %% [markdown]
# <h2 style="padding: 0.5rem; background-color: #513d5c; color: white;">Univariate Analysis</h2>

# %% [markdown]
# <div style="width: 20%;">
#     <h3 style="background-color: #a07fb3; color: white; padding: 0.5rem 0.5rem; text-align: center; vertical-align: middle; box-shadow: 5px 5px #4d3e66;">🎯 Inventory Data</h3>
#     <div style="margin: 1.5rem 0;"></div>
# </div>

# %%
inventory_df.head(10)
# Out:
#                         _id  itemCode       title  \
# 0  67b5d1d3965831513a85d8be       100  Ventilator
# 1  67b5d1d3965831513a85d8be       100  Ventilator
# 2  67b5d1d3965831513a85d8be       100  Ventilator
# 3  67b5d1d3965831513a85d8be       100  Ventilator
# 4  67b5d1d3965831513a85d8be       100  Ventilator
# 5  67b5d1d3965831513a85d8be       100  Ventilator
# 6  67b5d1d3965831513a85d8be       100  Ventilator
# 7  67b5d1d3965831513a85d8be       100  Ventilator
# 8  67b5d1d3965831513a85d8be       100  Ventilator
# 9  67b5d1d3965831513a85d8be       100  Ventilator
#
#                                          description   category abcCategory  \
# 0  A medical device that supports or takes over b...  Equipment           C
# 1  A medical device that supports or takes over b...  Equipment           C
# 2  A medical device that supports or takes over b...  Equipment           C
# 3  A medical device that supports or takes over b...  Equipment           C
# 4  A medical device that supports or takes over b...  Equipment           C
# 5  A medical device that supports or takes over b...  Equipment           C
# 6  A medical device that supports or takes over b...  Equipment           C
# 7  A medical device that supports or takes over b...  Equipment           C
# 8  A medical device that supports or takes over b...  Equipment           C
# 9  A medical device that supports or takes over b...  Equipment           C
#
#    minStockLevel  maxStockLevel                 createdBy  status  \
# 0              3             25  67b1fdb293bfc8e17f896b31  active
# 1              3             25  67b1fdb293bfc8e17f896b31  active
# 2              3             25  67b1fdb293bfc8e17f896b31  active
# 3              3             25  67b1fdb293bfc8e17f896b31  active
# 4              3             25  67b1fdb293bfc8e17f896b31  active
# 5              3             25  67b1fdb293bfc8e17f896b31  active
# 6              3             25  67b1fdb293bfc8e17f896b31  active
# 7              3             25  67b1fdb293bfc8e17f896b31  active
# 8              3             25  67b1fdb293bfc8e17f896b31  active
# 9              3             25  67b1fdb293bfc8e17f896b31  active
#
#                   createdAt       date stock_status  unit_cost  current_stock  \
# 0  2025-02-19T12:42:59.839Z 2022-01-01    Available    2628329             22
# 1  2025-02-19T12:42:59.839Z 2022-01-02    Available    3140148             22
# 2  2025-02-19T12:42:59.839Z 2022-01-03    Available    2900449             18
# 3  2025-02-19T12:42:59.839Z 2022-01-04    Available    3160811              8
# 4  2025-02-19T12:42:59.839Z 2022-01-05    Available    2502553             21
# 5  2025-02-19T12:42:59.839Z 2022-01-06    Available    3009553             10
# 6  2025-02-19T12:42:59.839Z 2022-01-07    Available    3144247             19
# 7  2025-02-19T12:42:59.839Z 2022-01-08    Available    2422728              7
# 8  2025-02-19T12:42:59.839Z 2022-01-09    Available    2347192             18
# 9  2025-02-19T12:42:59.839Z 2022-01-10    Available    2081183             22
#
#    avg_usage_per_day                      vendor_name    vendor_contact  \
# 0                  5  Coleman-Bailey Medical Supplies  +63 906 473 8909
# 1                  1     Wang-Foster Medical Supplies  +63 922 748 0407
# 2                  1       Wu-Flores Medical Supplies  +63 973 346 5410
# 3                  1       Wu-Flores Medical Supplies  +63 973 346 5410
# 4                  1     Wang-Foster Medical Supplies  +63 922 748 0407
# 5                  4       Wu-Flores Medical Supplies  +63 973 346 5410
# 6                  3       Wu-Flores Medical Supplies  +63 973 346 5410
# 7                  5       Miles Inc Medical Supplies  +63 951 553 0757
# 8                  1       Wu-Flores Medical Supplies  +63 973 346 5410
# 9                  3       Wu-Flores Medical Supplies  +63 973 346 5410
#
#    expiration_date     storageLocation
# 0              NaN  ICU Equipment Room
# 1              NaN  ICU Equipment Room
# 2              NaN  ICU Equipment Room
# 3              NaN  ICU Equipment Room
# 4              NaN  ICU Equipment Room
# 5              NaN  ICU Equipment Room
# 6              NaN  ICU Equipment Room
# 7              NaN  ICU Equipment Room
# 8              NaN  ICU Equipment Room
# 9              NaN  ICU Equipment Room

# %% [markdown]
# <div style="width: 20%;">
#     <h3 style="background-color: #a07fb3; color: white; padding: 0.5rem 0.5rem; text-align: center; vertical-align: middle; box-shadow: 5px 5px #4d3e66;">🎯 Patient Data</h3>
#     <div style="margin: 1.5rem 0;"></div>
# </div>

# %%
patient_df.sample(frac=1).head(30)
# Out:
#        diagnosis_id        date       primary_diagnosis procedure_performed  \
# 2872            169  2022-08-29               Pneumonia      Oxygen Therapy
# 27977          2318  2023-05-03                COVID-19         Chest X-Ray
# 9519            733  2023-05-31                Fracture             Casting
# 13928          1093  2022-03-30  Diabetes Complications          IV Therapy
# 31133          2544  2023-08-17                COVID-19      Oxygen Therapy
# 19148          1527  2024-07-15                  Stroke                 MRI
# 19659          1566  2023-08-05                  Stroke          Blood Test
# 9497            731  2024-12-11                Fracture     Pain Management
# 8602            667  2024-01-05                Fracture     Pain Management
# 17622          1401  2023-01-30  Diabetes Complications          IV Therapy
# 7694            603  2024-11-10                Fracture               X-Ray
# 29700          2442  2024-04-03                COVID-19      Oxygen Therapy
# 12830           994  2023-12-05   Myocardial Infarction      Defibrillation
# 9532            734  2023-01-20                Fracture             Casting
# 23073          1917  2023-12-11                  Sepsis          Blood Test
# 22686          1869  2024-09-24                  Sepsis          Blood Test
# 4376            302  2023-04-15            Appendicitis        Appendectomy
# 28896          2384  2022-08-24                COVID-19          Blood Test
# 722              43  2023-05-03               Pneumonia          IV Therapy
# 28034          2323  2022-09-16                COVID-19      Oxygen Therapy
# 5516            405  2023-12-04            Appendicitis          Blood Test
# 32052          2610  2023-03-09                COVID-19      Oxygen Therapy
# 19399          1546  2023-09-29                  Stroke          Blood Test
# 10158           779  2024-05-03                Fracture               X-Ray
# 5879            438  2023-10-09            Appendicitis          Blood Test
# 15193          1198  2023-09-27  Diabetes Complications      Wound Dressing
# 4405            304  2022-04-16            Appendicitis          Blood Test
# 14681          1156  2023-03-22  Diabetes Complications          IV Therapy
# 12248           941  2024-12-02   Myocardial Infarction          IV Therapy
# 7291            567  2023-11-09            Appendicitis        Appendectomy
#
#                  item_used   item_type
# 2872            Ventilator   Equipment
# 27977        X-Ray Machine   Equipment
# 9519          Cotton Rolls  Consumable
# 13928           Blood Bags  Consumable
# 31133         Hospital Bed   Equipment
# 19148          Face Shield  Consumable
# 19659               Gloves  Consumable
# 9497          Hospital Bed   Equipment
# 8602         Infusion Pump   Equipment
# 17622              Syringe  Consumable
# 7694                Gloves  Consumable
# 29700        Surgical Mask  Consumable
# 12830        Defibrillator   Equipment
# 9532              Bandages  Consumable
# 23073           Blood Bags  Consumable
# 22686              Syringe  Consumable
# 4376   Antiseptic Solution  Consumable
# 28896               Gloves  Consumable
# 722                IV Drip  Consumable
# 28034        Surgical Mask  Consumable
# 5516                Gloves  Consumable
# 32052        Surgical Mask  Consumable
# 19399               Gloves  Consumable
# 10158               Gloves  Consumable
# 5879                Gloves  Consumable
# 15193         Cotton Rolls  Consumable
# 4405                Gloves  Consumable
# 14681              IV Drip  Consumable
# 12248              IV Drip  Consumable
# 7291   Antiseptic Solution  Consumable

# %% [markdown]
# ### Most Common Diagnosis Type (2022-2024)

# %%
patient_df['primary_diagnosis'].value_counts()
# Out:
# primary_diagnosis
# COVID-19                  5348
# Diabetes Complications    5124
# Appendicitis              4642
# Fracture                  3920
# Pneumonia                 3009
# Severe Burns              2556
# Stroke                    2288
# Myocardial Infarction     2255
# Sepsis                    2224
# Traumatic Brain Injury    1848
# Name: count, dtype: int64

# %%
order = patient_df['primary_diagnosis'].value_counts().index

plt.figure(figsize=(12, 6))
sns.countplot(patient_df, x='primary_diagnosis', order=order)

plt.title('Most Common Diagnosis Types (2022-2024)')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ### Consumable/Equipment Usage on Patients

# %%
patient_df['item_used'].value_counts()
# Out:
# item_used
# Gloves                 7553
# Syringe                3296
# Cotton Rolls           2782
# Surgical Mask          2678
# Gown                   2340
# IV Drip                2134
# Infusion Pump          2134
# Face Shield            2014
# Antiseptic Solution    2002
# Hospital Bed           1605
# Bandages               1342
# Blood Bags              910
# X-Ray Machine           839
# Ventilator              691
# MRI Scanner             308
# ECG Machine             205
# Defibrillator           205
# Wheelchair              176
# Name: count, dtype: int64

# %%
order = patient_df['item_used'].value_counts().index

plt.figure(figsize=(12, 6))
plt.title('Total Item Usage on Patients')
plt.xticks(rotation=30)
sns.countplot(patient_df, x='item_used', order = order)
plt.show()

# %% [markdown]
# <h2 style="padding: 0.5rem; background-color: #513d5c; color: white;">Bivariate Analysis</h2>

# %% [markdown]
# ### Consumable - Mean Usage Per Day

# %%
consumable_avg_usage = inventory_df[inventory_df['category'] == 'Consumable'].groupby(inventory_df['title'])[['avg_usage_per_day']].mean()
consumable_avg_usage = consumable_avg_usage.reset_index().sort_values(by='avg_usage_per_day', ascending=False)
consumable_avg_usage
# Out:
#                  title  avg_usage_per_day
# 8        Surgical Mask        1768.195146
# 9              Syringe        1111.834297
# 1             Bandages         909.330791
# 5               Gloves         601.610087
# 4          Face Shield         452.088608
# 0  Antiseptic Solution         302.795918
# 6                 Gown         301.953422
# 3         Cotton Rolls         174.593237
# 7              IV Drip         124.933010
# 2           Blood Bags          84.977077

# %%
plt.figure(figsize=(12, 6))
sns.barplot(consumable_avg_usage, x='title', y='avg_usage_per_day')

plt.title('Consumables Average Daily Usage Ranking')
plt.xlabel('Item Name')
plt.ylabel('Average Daily Usage')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ### Equipment - Mean Usage Per Day

# %%
equipment_avg_usage = inventory_df[inventory_df['category'] == 'Equipment'].groupby(inventory_df['title'])[['avg_usage_per_day']].mean()
equipment_avg_usage = equipment_avg_usage.reset_index().sort_values(by='avg_usage_per_day', ascending=False)
equipment_avg_usage
# Out:
#            title  avg_usage_per_day
# 3  Infusion Pump           9.910405
# 5     Ventilator           2.974609
# 6     Wheelchair           2.521318
# 1    ECG Machine           1.512573
# 2   Hospital Bed           1.500000
# 4    MRI Scanner           0.533463
# 0   Defibrilator           0.516811
# 7  X-Ray-Machine           0.492424

# %%
plt.figure(figsize=(12, 6))
sns.barplot(equipment_avg_usage, x='title', y='avg_usage_per_day')

plt.title('Equipment Average Daily Usage Ranking')
plt.xlabel('Item Name')
plt.ylabel('Average Daily Usage')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# ### Consumable vs Equipment - Mean Usage Per Day

# %%
item_top_usage = pd.concat([consumable_avg_usage.iloc[[0]], equipment_avg_usage.iloc[[0]]])
item_top_usage
# Out:
#            title  avg_usage_per_day
# 8  Surgical Mask        1768.195146
# 3  Infusion Pump           9.910405

# %%
plt.figure(figsize=(7, 6))
plt.title('Mean Usage Difference of Top Used Consumable vs Equipment')
plt.xlabel('Item Name')
plt.ylabel('Average Daily Usage')
sns.barplot(item_top_usage, x='title', y='avg_usage_per_day')
plt.show()

# %% [markdown]
# <h1 style='font-size: 2.5rem; text-align: center;'>Feature Engineering</h1>

# %%
inventory_df
# Out:
#                             _id  itemCode         title  \
# 0      67b5d1d3965831513a85d8be       100    Ventilator
# 1      67b5d1d3965831513a85d8be       100    Ventilator
# 2      67b5d1d3965831513a85d8be       100    Ventilator
# 3      67b5d1d3965831513a85d8be       100    Ventilator
# 4      67b5d1d3965831513a85d8be       100    Ventilator
# ...                         ...       ...           ...
# 18643  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18644  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18645  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18646  67b5d1d3965831513a85d8cf       209  Cotton Rolls
# 18647  67b5d1d3965831513a85d8cf       209  Cotton Rolls
#
#                                              description    category  \
# 0      A medical device that supports or takes over b...   Equipment
# 1      A medical device that supports or takes over b...   Equipment
# 2      A medical device that supports or takes over b...   Equipment
# 3      A medical device that supports or takes over b...   Equipment
# 4      A medical device that supports or takes over b...   Equipment
# ...                                                  ...         ...
# 18643  Soft, absorbent materials used in medical appl...  Consumable
# 18644  Soft, absorbent materials used in medical appl...  Consumable
# 18645  Soft, absorbent materials used in medical appl...  Consumable
# 18646  Soft, absorbent materials used in medical appl...  Consumable
# 18647  Soft, absorbent materials used in medical appl...  Consumable
#
#       abcCategory  minStockLevel  maxStockLevel                 createdBy  \
# 0               C              3             25  67b1fdb293bfc8e17f896b31
# 1               C              3             25  67b1fdb293bfc8e17f896b31
# 2               C              3             25  67b1fdb293bfc8e17f896b31
# 3               C              3             25  67b1fdb293bfc8e17f896b31
# 4               C              3             25  67b1fdb293bfc8e17f896b31
# ...           ...            ...            ...                       ...
# 18643           C            300           2000  67b1fdb293bfc8e17f896b31
# 18644           C            300           2000  67b1fdb293bfc8e17f896b31
# 18645           C            300           2000  67b1fdb293bfc8e17f896b31
# 18646           C            300           2000  67b1fdb293bfc8e17f896b31
# 18647           C            300           2000  67b1fdb293bfc8e17f896b31
#
#        status                 createdAt       date stock_status  unit_cost  \
# 0      active  2025-02-19T12:42:59.839Z 2022-01-01    Available    2628329
# 1      active  2025-02-19T12:42:59.839Z 2022-01-02    Available    3140148
# 2      active  2025-02-19T12:42:59.839Z 2022-01-03    Available    2900449
# 3      active  2025-02-19T12:42:59.839Z 2022-01-04    Available    3160811
# 4      active  2025-02-19T12:42:59.839Z 2022-01-05    Available    2502553
# ...       ...                       ...        ...          ...        ...
# 18643  active  2025-02-19T12:42:59.839Z 2024-12-27    Available        149
# 18644  active  2025-02-19T12:42:59.839Z 2024-12-28    Available         87
# 18645  active  2025-02-19T12:42:59.839Z 2024-12-29    Available         64
# 18646  active  2025-02-19T12:42:59.839Z 2024-12-30    Available         91
# 18647  active  2025-02-19T12:42:59.839Z 2024-12-31    Available        119
#
#        current_stock  avg_usage_per_day  \
# 0                 22                  5
# 1                 22                  1
# 2                 18                  1
# 3                  8                  1
# 4                 21                  1
# ...              ...                ...
# 18643           1881                299
# 18644            606                296
# 18645           1100                178
# 18646            571                148
# 18647           1201                259
#
#                                       vendor_name    vendor_contact  \
# 0                 Coleman-Bailey Medical Supplies  +63 906 473 8909
# 1                    Wang-Foster Medical Supplies  +63 922 748 0407
# 2                      Wu-Flores Medical Supplies  +63 973 346 5410
# 3                      Wu-Flores Medical Supplies  +63 973 346 5410
# 4                    Wang-Foster Medical Supplies  +63 922 748 0407
# ...                                           ...               ...
# 18643                Wang-Foster Medical Supplies  +63 922 748 0407
# 18644             Coleman-Bailey Medical Supplies  +63 906 473 8909
# 18645                  Wu-Flores Medical Supplies  +63 973 346 5410
# 18646             Coleman-Bailey Medical Supplies  +63 906 473 8909
# 18647  Khan, Johnston and Nguyen Medical Supplies  +63 962 472 5531
#
#        expiration_date      storageLocation
# 0                  NaN   ICU Equipment Room
# 1                  NaN   ICU Equipment Room
# 2                  NaN   ICU Equipment Room
# 3                  NaN   ICU Equipment Room
# 4                  NaN   ICU Equipment Room
# ...                ...                  ...
# 18643     1.892938e+12  Medical Supply Room
# 18644     1.893024e+12  Medical Supply Room
# 18645     1.893110e+12  Medical Supply Room
# 18646     1.893197e+12  Medical Supply Room
# 18647     1.893283e+12  Medical Supply Room
#
# [18648 rows x 20 columns]

# %%
# Item Name, Date, Beginning Inventory, Ending Inventory, Monthly Usage
inventory_df1 = inventory_df.copy()
inventory_df1['date'] = pd.to_datetime(inventory_df1['date']) # Preprocessing: Datetime Conversion
inventory_df1['month'] = inventory_df1['date'].dt.to_period('M')
inventory_df1['year'] = inventory_df1['date'].dt.to_period('Y')

consumable_features = inventory_df1[inventory_df1['category'] == 'Consumable'].sort_values(['title', 'date']).groupby(['title', 'month']).agg(
        beginning_inventory = ('current_stock', 'first'),
        ending_inventory = ('current_stock', 'last'),
).reset_index()

consumable_features['category'] = 'Consumable'

equipment_features = inventory_df1[inventory_df1['category'] == 'Equipment'].sort_values(['title', 'date']).groupby(['title', 'year']).agg(
        beginning_inventory = ('current_stock', 'first'),
        ending_inventory = ('current_stock', 'last'),
).reset_index()

equipment_features['category'] = 'Equipment'

equipment_features = equipment_features.loc[equipment_features.index.repeat(12)].reset_index(drop=True)
equipment_features['month'] = pd.to_datetime(equipment_features['year'].astype(str) + '-' + np.tile(range(1, 13), len(equipment_features) // 12).astype(str)).dt.strftime('%Y-%m')
feature_df = pd.concat([consumable_features, equipment_features.drop(columns=['year'])])

# Annual Usage (For Equipment Turnover Rate)
annual_usage_df = inventory_df1.groupby(['title', 'year']).agg(annual_usage = ('avg_usage_per_day', 'sum')).reset_index()
feature_df['year'] = pd.to_datetime(feature_df['month'], format='%Y-%m')
feature_df['year'] = feature_df['year'].dt.to_period('Y')
feature_df = feature_df.merge(annual_usage_df, on=['title', 'year'], how='inner')

# Monthly Usage (For Consumable Turnover Rate) -> Shortcutting this by dividing annual usage by 12
feature_df['monthly_usage'] = feature_df['annual_usage'] / 12

'''

# To normalize in case the year is NOT YET COMPLETE (if year not complete = then the sum of the avg_usage is not really a year, but a few months only)
feature_df['annual_usage'] = feature_df.apply(lambda row: (row['annual_usage'] / row['months_available']) * 12, axis=1)

'''

# Unit Cost
cost_df = inventory_df.groupby('title')[['unit_cost']].mean().reset_index()
feature_df = feature_df.merge(cost_df, on='title', how='left')

# Annual Usage Value (AUG)
feature_df['annual_usage_value'] = feature_df['annual_usage'] * feature_df['unit_cost']

# Stock Turnover Rate
feature_df['stock_turnover_rate'] = np.where(feature_df['category'] == 'Consumable',
                                             feature_df['monthly_usage'] / ((feature_df['beginning_inventory'] + feature_df['ending_inventory']) / 2),
                                             feature_df['annual_usage'] / ((feature_df['beginning_inventory'] + feature_df['ending_inventory']) / 2),
                                            )

# Stock Variability
feature_df['stock_variability'] = inventory_df1.groupby('title')['current_stock'].transform(lambda x: x.std() / x.mean() if x.mean() != 0 else 0)

# Styling: Rerranging columns only
feature_df = feature_df[[
    'title', 'year', 'month', 'category', 'unit_cost', 'beginning_inventory', 'ending_inventory', 'annual_usage_value',
    'monthly_usage', 'annual_usage', 'stock_turnover_rate', 'stock_variability'
]]

feature_df
# Out:
#                    title  year    month    category     unit_cost  \
# 0    Antiseptic Solution  2022  2022-01  Consumable  4.554325e+02
# 1    Antiseptic Solution  2022  2022-02  Consumable  4.554325e+02
# 2    Antiseptic Solution  2022  2022-03  Consumable  4.554325e+02
# 3    Antiseptic Solution  2022  2022-04  Consumable  4.554325e+02
# 4    Antiseptic Solution  2022  2022-05  Consumable  4.554325e+02
# ..                   ...   ...      ...         ...           ...
# 643        X-Ray-Machine  2024  2024-08   Equipment  3.744346e+06
# 644        X-Ray-Machine  2024  2024-09   Equipment  3.744346e+06
# 645        X-Ray-Machine  2024  2024-10   Equipment  3.744346e+06
# 646        X-Ray-Machine  2024  2024-11   Equipment  3.744346e+06
# 647        X-Ray-Machine  2024  2024-12   Equipment  3.744346e+06
#
#      beginning_inventory  ending_inventory  annual_usage_value  monthly_usage  \
# 0                    958              2474        4.591761e+07    8401.833333
# 1                   2762              2992        4.591761e+07    8401.833333
# 2                   2227              1903        4.591761e+07    8401.833333
# 3                   2246              2570        4.591761e+07    8401.833333
# 4                   2524               562        4.591761e+07    8401.833333
# ..                   ...               ...                 ...            ...
# 643                    5                 8        5.841180e+08      13.000000
# 644                    5                 8        5.841180e+08      13.000000
# 645                    5                 8        5.841180e+08      13.000000
# 646                    5                 8        5.841180e+08      13.000000
# 647                    5                 8        5.841180e+08      13.000000
#
#      annual_usage  stock_turnover_rate  stock_variability
# 0          100822             4.896173           0.504353
# 1          100822             2.920345           0.504353
# 2          100822             4.068684           0.504353
# 3          100822             3.489133           0.504353
# 4          100822             5.445129           0.504353
# ..            ...                  ...                ...
# 643           156            24.000000           0.504353
# 644           156            24.000000           0.504353
# 645           156            24.000000           0.504353
# 646           156            24.000000           0.504353
# 647           156            24.000000           0.504353
#
# [648 rows x 12 columns]

# %% [markdown]
# <div style="width: 30%;">
#     <h3 style="background-color: #a07fb3; color: white; padding: 0.5rem 0.5rem; text-align: center; vertical-align: middle; box-shadow: 5px 5px #4d3e66;">🎯 Feature Importance</h3>
#     <div style="margin: 1.5rem 0;"></div>
# </div>

# %%
#feature_df[['title', 'category', 'year', 'annual_usage_value', 'stock_turnover_rate']].drop_duplicates(subset=['title', 'category', 'year']).sort_values(by='annual_usage_value')
feature_df[['title', 'category', 'year', 'annual_usage_value', 'stock_turnover_rate']].drop_duplicates(subset=['title', 'category', 'year']).sort_values(by='stock_turnover_rate')
# Out:
#                    title    category  year  annual_usage_value  \
# 72            Blood Bags  Consumable  2022        2.898883e+07
# 252              IV Drip  Consumable  2022        9.805139e+06
# 264              IV Drip  Consumable  2023        9.581384e+06
# 276              IV Drip  Consumable  2024        1.023584e+07
# 96            Blood Bags  Consumable  2024        2.817490e+07
# 132         Cotton Rolls  Consumable  2024        6.010519e+06
# 84            Blood Bags  Consumable  2023        2.763260e+07
# 300        Surgical Mask  Consumable  2023        3.376805e+06
# 180               Gloves  Consumable  2022        2.007247e+06
# 24   Antiseptic Solution  Consumable  2024        4.700792e+07
# 240                 Gown  Consumable  2024        1.729707e+07
# 204               Gloves  Consumable  2024        2.033498e+06
# 288        Surgical Mask  Consumable  2022        3.385472e+06
# 228                 Gown  Consumable  2023        1.697106e+07
# 336              Syringe  Consumable  2023        8.106888e+06
# 0    Antiseptic Solution  Consumable  2022        4.591761e+07
# 120         Cotton Rolls  Consumable  2023        6.167361e+06
# 216                 Gown  Consumable  2022        1.808637e+07
# 108         Cotton Rolls  Consumable  2022        6.013338e+06
# 192               Gloves  Consumable  2023        2.064395e+06
# 432         Hospital Bed   Equipment  2022        1.758157e+07
# 312        Surgical Mask  Consumable  2024        3.415454e+06
# 60              Bandages  Consumable  2024        9.686039e+06
# 348              Syringe  Consumable  2024        8.195244e+06
# 156          Face Shield  Consumable  2023        1.324903e+07
# 48              Bandages  Consumable  2023        9.167474e+06
# 444         Hospital Bed   Equipment  2023        1.758157e+07
# 12   Antiseptic Solution  Consumable  2023        4.897675e+07
# 456         Hospital Bed   Equipment  2024        1.972566e+07
# 168          Face Shield  Consumable  2024        1.298661e+07
# 324              Syringe  Consumable  2022        7.924738e+06
# 144          Face Shield  Consumable  2022        1.305448e+07
# 36              Bandages  Consumable  2022        9.952267e+06
# 636        X-Ray-Machine   Equipment  2024        5.841180e+08
# 624        X-Ray-Machine   Equipment  2023        6.852154e+08
# 384         Defibrilator   Equipment  2024        9.538639e+07
# 372         Defibrilator   Equipment  2023        8.704659e+07
# 360         Defibrilator   Equipment  2022        9.799257e+07
# 600           Wheelchair   Equipment  2024        1.380501e+07
# 540           Ventilator   Equipment  2022        2.417171e+09
# 576           Wheelchair   Equipment  2022        1.281358e+07
# 420          ECG Machine   Equipment  2024        1.348990e+08
# 588           Wheelchair   Equipment  2023        1.246808e+07
# 564           Ventilator   Equipment  2024        2.405426e+09
# 408          ECG Machine   Equipment  2023        1.254061e+08
# 528          MRI Scanner   Equipment  2024        6.527243e+09
# 612        X-Ray-Machine   Equipment  2022        6.777267e+08
# 504          MRI Scanner   Equipment  2022        6.827347e+09
# 516          MRI Scanner   Equipment  2023        7.277501e+09
# 552           Ventilator   Equipment  2023        2.332605e+09
# 396          ECG Machine   Equipment  2022        1.304024e+08
# 468        Infusion Pump   Equipment  2022        5.754385e+08
# 480        Infusion Pump   Equipment  2023        5.492294e+08
# 492        Infusion Pump   Equipment  2024        5.817420e+08
#
#      stock_turnover_rate
# 72              2.039973
# 252             2.126723
# 264             2.266253
# 276             2.654310
# 96              2.849624
# 132             3.043119
# 84              3.493974
# 300             3.807405
# 180             3.995318
# 24              4.143224
# 240             4.233140
# 204             4.304621
# 288             4.348889
# 228             4.650858
# 336             4.741363
# 0               4.896173
# 120             5.007684
# 216             5.658880
# 108             5.758049
# 192             5.973314
# 432             6.036810
# 312             6.176095
# 60              6.403690
# 348             6.569618
# 156             6.890459
# 48              7.292592
# 444             7.748031
# 12              8.286254
# 456             8.363636
# 168             8.714594
# 324             9.126463
# 144             9.750095
# 36             10.609877
# 636            24.000000
# 624            26.142857
# 384            28.153846
# 372            33.400000
# 360            37.600000
# 600            39.956522
# 540            52.769231
# 576            53.312500
# 420            54.000000
# 588            69.166667
# 564            75.851852
# 408           100.400000
# 528           116.000000
# 612           181.000000
# 504           182.000000
# 516           194.000000
# 552           220.666667
# 396           261.000000
# 468           330.380952
# 480           367.888889
# 492           779.333333

# %% [markdown]
# <div style="width: 30%;">
#     <h3 style="background-color: #a07fb3; color: white; padding: 0.5rem 0.5rem; text-align: center; vertical-align: middle; box-shadow: 5px 5px #4d3e66;">🎯 Feature Selection</h3>
#     <div style="margin: 1.5rem 0;"></div>
# </div>

# %%
#X_features = ['category', 'annual_usage_value', 'stock_turnover_rate', 'unit_cost', 'monthly_usage', 'annual_usage', 'stock_variability']
#X_features = ['annual_usage_value', 'unit_cost', 'monthly_usage', 'annual_usage', 'stock_turnover_rate', 'stock_variability']
#X_features = ['category', 'annual_usage_value', 'stock_turnover_rate', 'unit_cost', 'stock_variability']
#X_features = ['category', 'annual_usage_value', 'stock_turnover_rate', 'stock_variability']
X_features = ['category', 'annual_usage_value', 'stock_turnover_rate']
X = feature_df[X_features]
X
# Out:
#        category  annual_usage_value  stock_turnover_rate
# 0    Consumable        4.591761e+07             4.896173
# 1    Consumable        4.591761e+07             2.920345
# 2    Consumable        4.591761e+07             4.068684
# 3    Consumable        4.591761e+07             3.489133
# 4    Consumable        4.591761e+07             5.445129
# ..          ...                 ...                  ...
# 643   Equipment        5.841180e+08            24.000000
# 644   Equipment        5.841180e+08            24.000000
# 645   Equipment        5.841180e+08            24.000000
# 646   Equipment        5.841180e+08            24.000000
# 647   Equipment        5.841180e+08            24.000000
#
# [648 rows x 3 columns]

# %% [markdown]
# <h1 style='font-size: 2.5rem; text-align: center;'>Clustering Model - ABC Analysis</h1>

# %%
#cat_features = ['category']
#num_features = ['annual_usage_value', 'stock_turnover_rate', 'unit_cost', 'monthly_usage', 'annual_usage', 'stock_variability']

num_features = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = X.select_dtypes(include=['object']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), num_features),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('kmeans', KMeans(n_clusters=3, random_state=1))
])

pipeline.fit(X)
clusters = pipeline.predict(X)
feature_df1 = feature_df.copy()
feature_df1['cluster'] = clusters

# Rename clusters to A, B, C based on AUV values
cluster_mapping = {
    feature_df1.groupby('cluster')['annual_usage_value'].mean().idxmax(): 'A',
    feature_df1.groupby('cluster')['annual_usage_value'].mean().idxmin(): 'C'
}
cluster_mapping = {k: cluster_mapping.get(k, 'B') for k in range(3)}

# Map cluster labels to A, B, C
feature_df1['ABC_category'] = feature_df1['cluster'].map(cluster_mapping)
feature_df1
# Out:
#                    title  year    month    category     unit_cost  \
# 0    Antiseptic Solution  2022  2022-01  Consumable  4.554325e+02
# 1    Antiseptic Solution  2022  2022-02  Consumable  4.554325e+02
# 2    Antiseptic Solution  2022  2022-03  Consumable  4.554325e+02
# 3    Antiseptic Solution  2022  2022-04  Consumable  4.554325e+02
# 4    Antiseptic Solution  2022  2022-05  Consumable  4.554325e+02
# ..                   ...   ...      ...         ...           ...
# 643        X-Ray-Machine  2024  2024-08   Equipment  3.744346e+06
# 644        X-Ray-Machine  2024  2024-09   Equipment  3.744346e+06
# 645        X-Ray-Machine  2024  2024-10   Equipment  3.744346e+06
# 646        X-Ray-Machine  2024  2024-11   Equipment  3.744346e+06
# 647        X-Ray-Machine  2024  2024-12   Equipment  3.744346e+06
#
#      beginning_inventory  ending_inventory  annual_usage_value  monthly_usage  \
# 0                    958              2474        4.591761e+07    8401.833333
# 1                   2762              2992        4.591761e+07    8401.833333
# 2                   2227              1903        4.591761e+07    8401.833333
# 3                   2246              2570        4.591761e+07    8401.833333
# 4                   2524               562        4.591761e+07    8401.833333
# ..                   ...               ...                 ...            ...
# 643                    5                 8        5.841180e+08      13.000000
# 644                    5                 8        5.841180e+08      13.000000
# 645                    5                 8        5.841180e+08      13.000000
# 646                    5                 8        5.841180e+08      13.000000
# 647                    5                 8        5.841180e+08      13.000000
#
#      annual_usage  stock_turnover_rate  stock_variability  cluster  \
# 0          100822             4.896173           0.504353        0
# 1          100822             2.920345           0.504353        0
# 2          100822             4.068684           0.504353        0
# 3          100822             3.489133           0.504353        0
# 4          100822             5.445129           0.504353        0
# ..            ...                  ...                ...      ...
# 643           156            24.000000           0.504353        2
# 644           156            24.000000           0.504353        2
# 645           156            24.000000           0.504353        2
# 646           156            24.000000           0.504353        2
# 647           156            24.000000           0.504353        2
#
#     ABC_category
# 0              C
# 1              C
# 2              C
# 3              C
# 4              C
# ..           ...
# 643            B
# 644            B
# 645            B
# 646            B
# 647            B
#
# [648 rows x 14 columns]

# %% [markdown]
# # Model Evaluation

# %%
plt.figure(figsize=(11, 6))
sns.countplot(feature_df1, x='ABC_category')
plt.show()

# %%
feature_df1.groupby('ABC_category')[['title']].count().reset_index()
# Out:
#   ABC_category  title
# 0            A     36
# 1            B    252
# 2            C    360

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(feature_df1, x='title', y='annual_usage_value', hue='ABC_category', palette='Set1', s=100)
plt.title('ABC Analysis Clusters')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Model Export

# %%
abc_clusters_csv = './data/abc_clusters.csv'

if not os.path.exists(abc_clusters_csv):
    feature_df1.to_csv(abc_clusters_csv, index=False)

# %%
# Export model file
joblib.dump(pipeline, './models/hospital_abc_clf.joblib')
# Out:
# ['./models/hospital_abc_clf.joblib']
